# %% [markdown]
# This script is used to create "negative" captions for images from the Flickr30K test dataset using MLM. Steps are roughly as follows:
# ### 1. Identification of objects to mask and replace in captions
#  * We use nltk parsing to extract noun phrases or objects that are candidates for substitution in the captions for the different images
#
# ### 2. Apply MLM to get candidate substitution phrases for masked words
#  * We apply BertForMaskedLM on masked sentences
#
# ### 3. Analysis of candidate "negative" captions
#   * Not all replacement words/ phrases are appropriate. We apply some post-processing to select reasonable candidates from the MLM

# %% [markdown]
# ## Inital Set-up

# %%
# !pip install transformers
# !pip install nltk
# Out:
# Collecting transformers
#   Downloading transformers-4.19.0-py3-none-any.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 5.2 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.6.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 1.7 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 27.9 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 49.4 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.6.0 pyyaml-6.0 tokenizers-0.12.1 transformers-4.19.0
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)

# %%
import os, sys
import pandas as pd
import numpy as np
import json
import spacy
import en_core_web_sm
import nltk
from nltk import word_tokenize
from nltk import pos_tag
from transformers import BertTokenizer, BertForMaskedLM
from torch.nn import functional as F
import torch
import re
from nltk.corpus import wordnet
from tqdm.auto import tqdm
import pickle

import logging

logging.basicConfig(level=logging.DEBUG)

pipeline_device = 0 if torch.cuda.is_available() else -1
print(f"Using device: {pipeline_device}")
model_type = "roberta-large"
k=10
output_base = f"output/masked_inst-{model_type}-{k}"
# Out:
# Using device: -1

# %%
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd "/content/gdrive/MyDrive/NYU/DL Systems/final_project/"
# !ls
# Out:
# /content/gdrive/.shortcut-targets-by-id/1mkkPzbGFRuZ52OVppGv8cKxDIdSjwPYf/final_project
#  data					  flickr_eval.py
# 'DL Systems Final Presentation.gslides'   flickr_eval.sh
#  eval_flickr.ipynb			  mdetr
# 'Experiment Tracker.gsheet'		  MLM_object_replacement.ipynb
# 'Final Presentation.gslides'		  output

# %%
# data_dir = '/content/gdrive/MyDrive/DL_systems/final_project/data/'
# flickr_anns = json.load(open(os.path.join(data_dir, 'final_flickr_mergedGT_test.json'),'r'))
with open("data/final_flickr_mergedGT_test.json") as f:
  flickr_anns = json.load(f)

len(flickr_anns['images']), len(flickr_anns['annotations'])
# Out:
# (4969, 14481)

# %%
flickr_anns.keys()
# Out:
# dict_keys(['info', 'licenses', 'images', 'annotations', 'categories'])

# %% [markdown]
# Example of image data in annotation file:

# %%
flickr_anns['images'][0]
# Out:
# {'caption': 'Several climbers in a row are climbing the rock while the man in red watches and holds the line .',
#  'dataset_name': 'flickr',
#  'file_name': '1016887272.jpg',
#  'height': '500',
#  'id': 153901,
#  'original_img_id': 1016887272,
#  'sentence_id': 0,
#  'tokens_negative': [[0, 97]],
#  'tokens_positive_eval': [[[0, 16]],
#   [[39, 47]],
#   [[54, 61]],
#   [[65, 68]],
#   [[87, 95]]],
#  'width': '333'}

# %%
flickr_anns['images'][5]
# Out:
# {'caption': 'Two children playing on the beach in the sand with the ocean in the background',
#  'dataset_name': 'flickr',
#  'file_name': '7162685234.jpg',
#  'height': '333',
#  'id': 153906,
#  'original_img_id': 7162685234,
#  'sentence_id': 0,
#  'tokens_negative': [[0, 78]],
#  'tokens_positive_eval': [[[0, 12]], [[24, 33]], [[37, 45]], [[51, 60]]],
#  'width': '500'}

# %% [markdown]
# Example of annotation data in annotation file:

# %%
flickr_anns['annotations'][0]
# Out:
# {'area': 21186.0,
#  'bbox': [74.0, 302.0, 107.0, 198.0],
#  'category_id': 1,
#  'id': 430844,
#  'image_id': 153901,
#  'iscrowd': 0,
#  'phrase_ids': 3,
#  'tokens_positive': [[54, 61]]}

# %% [markdown]
# ## Identification of objects to mask and replace in captions

# %%
article_list = ['the', 'a', 'an']
def parse_NP(sentence):
    '''
    Function for extracting noun phrases from sentences (these will be objects and object + modifiers we will be replacing to create negative captions)
    '''

    #Define grammar for parsing tree
    grammar = """NP: {<DT>?<JJ>*<NN.*>+}
                    RELATION: {<V.*>}
                                {<DT>?<JJ>*<NN.*>+}
                    ENTITY: {<NN.*>}"""
    
    parser = nltk.RegexpParser(grammar)
    NP_list = [' '.join(leaf[0] for leaf in tree.leaves()) for tree in parser.parse(nltk.pos_tag(nltk.word_tokenize(sentence))).subtrees() if tree.label() =='NP']
    
    #remove articles from NP
    NP_list = [' '.join([w for w in str.split(np,' ') if str.lower(w) not in(article_list)]) for np in NP_list]
    return NP_list

# %%
'''Update annotations dictionary (image keys specificially to include noun phrases and ids associated w/ them)
This is important because these NPs are what we are going to find candidate replacements for using MLM
Each caption can have multiople NPs so we need to have ids associated with each to map back to the original image/caption once we tokenize all the captions and load them in dataloader
'''
np_id = 0
for i, img in enumerate(flickr_anns['images']):
    img['NPs'] = parse_NP(img['caption'])
    img['NP_ids'] = []
    for i in range(len(img['NPs'])):
        #Add in ID for noun phrases for mapping back when we add to dataset
        img['NP_ids'].append(np_id)
        np_id += 1

# %%
people_words = np.array(['man', 'woman', 'men', 'women', 'children', 'child', 'girl', 'boy', 'boys', 'girls', 'father', 'fathers', 'son', 'sons', 'husband', 'husbands', 'mother','mothers', 'parent', 'parents', 'daughter', 'daughters', 'wife', 'wives',
                  'spouse', 'spouses', 'partner', 'partners', 'brother', 'brothers', 'sister', 'sisters', 'sibling', 'siblings', 'grandfather','grandfathers',	'grandmother', 'grandmothers',	'grandparents', 'uncle', 'uncles', 'aunt', 'aunts',
                   'nephew', 'nephews', 'niece', 'nieces', 'cousin', 'cousins', 'person', 'people', 'guy', 'guys', 'lady', 'ladies'])
pronoun_words = np.array(["this", "that", "these", "those", "another", "anybody", "anyone", "anything", "each", "either", "enough", "everybody", "everyone",
                "everything", "little", "much", "neither", "nobody", "no one", "nothing", "one", "other", "somebody",
                "something", "both", "few", "fewer", "many", "others", "several", "all", "any", "more", "most",
                "someone", "none", "some", "such", "who", "whom", "whose", "what", "which", 'it', 'them', 'they', 'her', 'she', 'him', 'he', 'i', 'I'])

# %% [markdown]
# We're going through every image and its associated caption.
# Each caption has a set of noun-phrases (NPs) which we can use
# as candidate words to mask out.

# %%
import re

MASK_TOKEN = "<mask>"

def word_count(np, caption):
    # https://stackoverflow.com/questions/17268958/finding-occurrences-of-a-word-in-a-string-in-python-3
    return sum(1 for _ in re.finditer(r'\b%s\b' % re.escape(np), caption))

def has_banned_words(NP):
    # Check if any of the people_words or pronoun_words are this word
    return NP in people_words or NP in pronoun_words

def is_valid(np, caption):
    if len(np.split(' ')) > 1:
        # logging.debug(f"IGNORE: NP '{np}' is multiple words")
        return False

    if word_count(np, caption) > 1:
        # logging.debug(f"IGNORE: Caption '{caption}' contains multiple instances of mask word '{np}'")
        return False

    if has_banned_words(np):
        # logging.debug(f"IGNORE: NP '{np}' contains banned words")
        return False

    return True


def replace_mask_word(word, caption):
    return re.sub(rf'\b{word}\b', MASK_TOKEN, caption)

cnt = 0
for image_idx, img in enumerate(flickr_anns['images']):
    caption = img['caption']
    NPs = img['NPs']
    masked_captions = []
    masked_nps = []

    for NP in NPs:
        if not is_valid(NP, caption):
            continue

        # NP has passed all tests, so lets replace the NP with the mask
        masked_caption = replace_mask_word(NP, caption)

        # Save this masked caption
        masked_captions.append(masked_caption)
        masked_nps.append(NP)

    # Store the masked captions back to the instance
    img['masked_captions'] = masked_captions
    img['masked_nps'] = masked_nps

    # Store the instance back in the dictionary
    flickr_anns['images'][image_idx] = img

masked_count = 0
for img in flickr_anns['images']:
    masked_count += len(img['masked_captions'])

print(f"# masked captions: {masked_count}")
# Out:
# # masked captions: 8149

# %% [markdown]
# ### Filter out instances with no viable masked captions

# %%
instances = [inst for inst in flickr_anns["images"] if len(inst['masked_captions']) > 0]

print(len(instances))
instances[0]
# Out:
# 4158
# {'NP_ids': [0, 1, 2, 3, 4, 5],
#  'NPs': ['Several climbers', 'row', 'rock', 'man', 'red watches', 'line'],
#  'caption': 'Several climbers in a row are climbing the rock while the man in red watches and holds the line .',
#  'dataset_name': 'flickr',
#  'file_name': '1016887272.jpg',
#  'height': '500',
#  'id': 153901,
#  'masked_captions': ['Several climbers in a <mask> are climbing the rock while the man in red watches and holds the line .',
#   'Several climbers in a row are climbing the <mask> while the man in red watches and holds the line .',
#   'Several climbers in a row are climbing the rock while the man in red watches and holds the <mask> .'],
#  'masked_nps': ['row', 'rock', 'line'],
#  'original_img_id': 1016887272,
#  'sentence_id': 0,
#  'tokens_negative': [[0, 97]],
#  'tokens_positive_eval': [[[0, 16]],
#   [[39, 47]],
#   [[54, 61]],
#   [[65, 68]],
#   [[87, 95]]],
#  'width': '333'}

# %% [markdown]
# ## Apply MLM to get candidate substitution phrases for masked words

# %%
from transformers import pipeline
unmasker = pipeline('fill-mask', model=model_type, top_k=k, device=pipeline_device)
# unmasker(["Hello I'm a <mask> computer scientist.", "The man leans over to pick up a <mask> from the ground"])
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /roberta-large/resolve/main/config.json HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 140003114825424 on /root/.cache/huggingface/transformers/dea67b44b38d504f2523f3ddb6acb601b23d67bee52c942da336fa1283100990.94cae8b3a8dbab1d59b9d4827f7ce79e73124efa6bb970412cd503383a95f373.lock
# DEBUG:filelock:Lock 140003114825424 acquired on /root/.cache/huggingface/transformers/dea67b44b38d504f2523f3ddb6acb601b23d67bee52c942da336fa1283100990.94cae8b3a8dbab1d59b9d4827f7ce79e73124efa6bb970412cd503383a95f373.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /roberta-large/resolve/main/config.json HTTP/1.1" 200 482
# Downloading:   0%|          | 0.00/482 [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140003114825424 on /root/.cache/huggingface/transformers/dea67b44b38d504f2523f3ddb6acb601b23d67bee52c942da336fa1283100990.94cae8b3a8dbab1d59b9d4827f7ce79e73124efa6bb970412cd503383a95f373.lock
# DEBUG:filelock:Lock 140003114825424 released on /root/.cache/huggingface/transformers/dea67b44b38d504f2523f3ddb6acb601b23d67bee52c942da336fa1283100990.94cae8b3a8dbab1d59b9d4827f7ce79e73124efa6bb970412cd503383a95f373.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /roberta-large/resolve/main/config.json HTTP/1.1" 200 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /roberta-large/resolve/main/pytorch_model.bin HTTP/1.1" 302 0
# DEBUG:filelock:Attempting to acquire lock 140003093625552 on /root/.cache/huggingface/transformers/8e36ec2f5052bec1e79e139b84c2c3089cb647694ba0f4f634fec7b8258f7c89.c43841d8c5cd23c435408295164cda9525270aa42cd0cc9200911570c0342352.lock
# DEBUG:filelock:Lock 140003093625552 acquired on /root/.cache/huggingface/transformers/8e36ec2f5052bec1e79e139b84c2c3089cb647694ba0f4f634fec7b8258f7c89.c43841d8c5cd23c435408295164cda9525270aa42cd0cc9200911570c0342352.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): cdn-lfs.huggingface.co:443
# DEBUG:urllib3.connectionpool:https://cdn-lfs.huggingface.co:443 "GET /roberta-large/36a10a8b694fadf9bf4f9049d14e257e88be45313ae02d882af9e60f39b8b2e8 HTTP/1.1" 200 1425941629
# Downloading:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140003093625552 on /root/.cache/huggingface/transformers/8e36ec2f5052bec1e79e139b84c2c3089cb647694ba0f4f634fec7b8258f7c89.c43841d8c5cd23c435408295164cda9525270aa42cd0cc9200911570c0342352.lock
# DEBUG:filelock:Lock 140003093625552 released on /root/.cache/huggingface/transformers/8e36ec2f5052bec1e79e139b84c2c3089cb647694ba0f4f634fec7b8258f7c89.c43841d8c5cd23c435408295164cda9525270aa42cd0cc9200911570c0342352.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /roberta-large/resolve/main/tokenizer_config.json HTTP/1.1" 404 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /roberta-large/resolve/main/config.json HTTP/1.1" 200 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /roberta-large/resolve/main/tokenizer_config.json HTTP/1.1" 404 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /roberta-large/resolve/main/vocab.json HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 140003091176272 on /root/.cache/huggingface/transformers/7c1ba2435b05451bc3b4da073c8dec9630b22024a65f6c41053caccf2880eb8f.d67d6b367eb24ab43b08ad55e014cf254076934f71d832bbab9ad35644a375ab.lock
# DEBUG:filelock:Lock 140003091176272 acquired on /root/.cache/huggingface/transformers/7c1ba2435b05451bc3b4da073c8dec9630b22024a65f6c41053caccf2880eb8f.d67d6b367eb24ab43b08ad55e014cf254076934f71d832bbab9ad35644a375ab.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /roberta-large/resolve/main/vocab.json HTTP/1.1" 200 898823
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140003091176272 on /root/.cache/huggingface/transformers/7c1ba2435b05451bc3b4da073c8dec9630b22024a65f6c41053caccf2880eb8f.d67d6b367eb24ab43b08ad55e014cf254076934f71d832bbab9ad35644a375ab.lock
# DEBUG:filelock:Lock 140003091176272 released on /root/.cache/huggingface/transformers/7c1ba2435b05451bc3b4da073c8dec9630b22024a65f6c41053caccf2880eb8f.d67d6b367eb24ab43b08ad55e014cf254076934f71d832bbab9ad35644a375ab.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /roberta-large/resolve/main/merges.txt HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 140003091201808 on /root/.cache/huggingface/transformers/20b5a00a80e27ae9accbe25672aba42ad2d4d4cb2c4b9359b50ca8e34e107d6d.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b.lock
# DEBUG:filelock:Lock 140003091201808 acquired on /root/.cache/huggingface/transformers/20b5a00a80e27ae9accbe25672aba42ad2d4d4cb2c4b9359b50ca8e34e107d6d.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /roberta-large/resolve/main/merges.txt HTTP/1.1" 200 456318
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140003091201808 on /root/.cache/huggingface/transformers/20b5a00a80e27ae9accbe25672aba42ad2d4d4cb2c4b9359b50ca8e34e107d6d.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b.lock
# DEBUG:filelock:Lock 140003091201808 released on /root/.cache/huggingface/transformers/20b5a00a80e27ae9accbe25672aba42ad2d4d4cb2c4b9359b50ca8e34e107d6d.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /roberta-large/resolve/main/tokenizer.json HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 140003092830416 on /root/.cache/huggingface/transformers/e16a2590deb9e6d73711d6e05bf27d832fa8c1162d807222e043ca650a556964.fc9576039592f026ad76a1c231b89aee8668488c671dfbe6616bab2ed298d730.lock
# DEBUG:filelock:Lock 140003092830416 acquired on /root/.cache/huggingface/transformers/e16a2590deb9e6d73711d6e05bf27d832fa8c1162d807222e043ca650a556964.fc9576039592f026ad76a1c231b89aee8668488c671dfbe6616bab2ed298d730.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /roberta-large/resolve/main/tokenizer.json HTTP/1.1" 200 1355863
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140003092830416 on /root/.cache/huggingface/transformers/e16a2590deb9e6d73711d6e05bf27d832fa8c1162d807222e043ca650a556964.fc9576039592f026ad76a1c231b89aee8668488c671dfbe6616bab2ed298d730.lock
# DEBUG:filelock:Lock 140003092830416 released on /root/.cache/huggingface/transformers/e16a2590deb9e6d73711d6e05bf27d832fa8c1162d807222e043ca650a556964.fc9576039592f026ad76a1c231b89aee8668488c671dfbe6616bab2ed298d730.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /roberta-large/resolve/main/added_tokens.json HTTP/1.1" 404 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /roberta-large/resolve/main/special_tokens_map.json HTTP/1.1" 404 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /roberta-large/resolve/main/tokenizer_config.json HTTP/1.1" 404 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /roberta-large/resolve/main/config.json HTTP/1.1" 200 0

# %%
unmasker("The <mask> is struggling to stay on the horse inside of the bullpen as he goes around the red , white , and blue barrel .")
# Out:
# [{'score': 0.14824217557907104,
#   'sequence': 'The veteran is struggling to stay on the horse inside of the bullpen as he goes around the red, white, and blue barrel.',
#   'token': 3142,
#   'token_str': ' veteran'},
#  {'score': 0.1481788605451584,
#   'sequence': 'The rookie is struggling to stay on the horse inside of the bullpen as he goes around the red, white, and blue barrel.',
#   'token': 4534,
#   'token_str': ' rookie'},
#  {'score': 0.12870417535305023,
#   'sequence': 'The horse is struggling to stay on the horse inside of the bullpen as he goes around the red, white, and blue barrel.',
#   'token': 5253,
#   'token_str': ' horse'},
#  {'score': 0.04824225232005119,
#   'sequence': 'The pitcher is struggling to stay on the horse inside of the bullpen as he goes around the red, white, and blue barrel.',
#   'token': 7659,
#   'token_str': ' pitcher'},
#  {'score': 0.028838209807872772,
#   'sequence': 'The starter is struggling to stay on the horse inside of the bullpen as he goes around the red, white, and blue barrel.',
#   'token': 6135,
#   'token_str': ' starter'},
#  {'score': 0.02465044893324375,
#   'sequence': 'The closer is struggling to stay on the horse inside of the bullpen as he goes around the red, white, and blue barrel.',
#   'token': 2789,
#   'token_str': ' closer'},
#  {'score': 0.023821232840418816,
#   'sequence': 'The bullpen is struggling to stay on the horse inside of the bullpen as he goes around the red, white, and blue barrel.',
#   'token': 11524,
#   'token_str': ' bullpen'},
#  {'score': 0.02290716953575611,
#   'sequence': 'The youngster is struggling to stay on the horse inside of the bullpen as he goes around the red, white, and blue barrel.',
#   'token': 16983,
#   'token_str': ' youngster'},
#  {'score': 0.022223234176635742,
#   'sequence': 'The reliever is struggling to stay on the horse inside of the bullpen as he goes around the red, white, and blue barrel.',
#   'token': 17188,
#   'token_str': ' reliever'},
#  {'score': 0.016398955136537552,
#   'sequence': 'The kid is struggling to stay on the horse inside of the bullpen as he goes around the red, white, and blue barrel.',
#   'token': 4607,
#   'token_str': ' kid'}]

# %% [markdown]
# ### Run `roberta-large` on our masked instances (only run once)

# %%
masked_instances = []
# Apply the MLM to each masked caption
for inst in tqdm(instances):
    # Each instance has 1 or more masked captions, which can be passed directly 
    # to the unmasking pipeline
    result = unmasker(inst["masked_captions"])

    # Pipeline returns a single-nested list if we pass only 1 item, so nest it
    if not isinstance(result[0], list):
        result = [result]

    # Save the model output with this instance
    inst["pred_captions"] = result
    # Store the instance
    masked_instances.append(inst)

# Store the results for fast loading later
with open(f"{output_base}.json", mode='w') as f:
    json.dump(masked_instances, f, indent=True)

with open(f'{output_base}.pkl', 'wb') as f:
    pickle.dump(masked_instances, f)
# Out:
#   0%|          | 0/4158 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/transformers/pipelines/base.py:998: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   UserWarning,

# %% [markdown]
# ## Load the `roberta-large` predictions

# %%
with open(f"{output_base}.pkl", mode='rb') as f:
    masked_instances = pickle.load(f)

print(len(masked_instances))
masked_instances[0]
# Out:
# 4158
# {'NP_ids': [0, 1, 2, 3, 4, 5],
#  'NPs': ['Several climbers', 'row', 'rock', 'man', 'red watches', 'line'],
#  'caption': 'Several climbers in a row are climbing the rock while the man in red watches and holds the line .',
#  'dataset_name': 'flickr',
#  'file_name': '1016887272.jpg',
#  'height': '500',
#  'id': 153901,
#  'masked_captions': ['Several climbers in a <mask> are climbing the rock while the man in red watches and holds the line .',
#   'Several climbers in a row are climbing the <mask> while the man in red watches and holds the line .',
#   'Several climbers in a row are climbing the rock while the man in red watches and holds the <mask> .'],
#  'masked_nps': ['row', 'rock', 'line'],
#  'original_img_id': 1016887272,
#  'pred_captions': [[{'score': 0.4581820070743561,
#     'sequence': 'Several climbers in a group are climbing the rock while the man in red watches and holds the line.',
#     'token': 333,
#     'token_str': ' group'},
#    {'score': 0.13606494665145874,
#     'sequence': 'Several climbers in a line are climbing the rock while the man in red watches and holds the line.',
#     'token': 516,
#     'token_str': ' line'},
#    {'score': 0.035771820694208145,
#     'sequence': 'Several climbers in a tent are climbing the rock while the man in red watches and holds the line.',
#     'token': 10178,
#     'token_str': ' tent'},
#    {'score': 0.034893348813056946,
#     'sequence': 'Several climbers in a pack are climbing the rock while the man in red watches and holds the line.',
#     'token': 6356,
#     'token_str': ' pack'},
#    {'score': 0.028061026707291603,
#     'sequence': 'Several climbers in a rope are climbing the rock while the man in red watches and holds the line.',
#     'token': 17434,
#     'token_str': ' rope'},
#    {'score': 0.02298501506447792,
#     'sequence': 'Several climbers in a harness are climbing the rock while the man in red watches and holds the line.',
#     'token': 15193,
#     'token_str': ' harness'},
#    {'score': 0.021093523129820824,
#     'sequence': 'Several climbers in a boat are climbing the rock while the man in red watches and holds the line.',
#     'token': 4293,
#     'token_str': ' boat'},
#    {'score': 0.020790671929717064,
#     'sequence': 'Several climbers in a canoe are climbing the rock while the man in red watches and holds the line.',
#     'token': 31728,
#     'token_str': ' canoe'},
#    {'score': 0.01914486661553383,
#     'sequence': 'Several climbers in a team are climbing the rock while the man in red watches and holds the line.',
#     'token': 165,
#     'token_str': ' team'},
#    {'score': 0.01769152283668518,
#     'sequence': 'Several climbers in a formation are climbing the rock while the man in red watches and holds the line.',
#     'token': 9285,
#     'token_str': ' formation'}],
#   [{'score': 0.22209276258945465,
#     'sequence': 'Several climbers in a row are climbing the mountain while the man in red watches and holds the line.',
#     'token': 6485,
#     'token_str': ' mountain'},
#    {'score': 0.18922972679138184,
#     'sequence': 'Several climbers in a row are climbing the wall while the man in red watches and holds the line.',
#     'token': 2204,
#     'token_str': ' wall'},
#    {'score': 0.08508194237947464,
#     'sequence': 'Several climbers in a row are climbing the rope while the man in red watches and holds the line.',
#     'token': 17434,
#     'token_str': ' rope'},
#    {'score': 0.05170845985412598,
#     'sequence': 'Several climbers in a row are climbing the tower while the man in red watches and holds the line.',
#     'token': 9368,
#     'token_str': ' tower'},
#    {'score': 0.04076767340302467,
#     'sequence': 'Several climbers in a row are climbing the rock while the man in red watches and holds the line.',
#     'token': 3152,
#     'token_str': ' rock'},
#    {'score': 0.027372626587748528,
#     'sequence': 'Several climbers in a row are climbing the cliff while the man in red watches and holds the line.',
#     'token': 15344,
#     'token_str': ' cliff'},
#    {'score': 0.02110517956316471,
#     'sequence': 'Several climbers in a row are climbing the ladder while the man in red watches and holds the line.',
#     'token': 16348,
#     'token_str': ' ladder'},
#    {'score': 0.018382301554083824,
#     'sequence': 'Several climbers in a row are climbing the tree while the man in red watches and holds the line.',
#     'token': 3907,
#     'token_str': ' tree'},
#    {'score': 0.016203707084059715,
#     'sequence': 'Several climbers in a row are climbing the pole while the man in red watches and holds the line.',
#     'token': 9438,
#     'token_str': ' pole'},
#    {'score': 0.014479214325547218,
#     'sequence': 'Several climbers in a row are climbing the peak while the man in red watches and holds the line.',
#     'token': 4996,
#     'token_str': ' peak'}],
#   [{'score': 0.4950436055660248,
#     'sequence': 'Several climbers in a row are climbing the rock while the man in red watches and holds the rope.',
#     'token': 17434,
#     'token_str': ' rope'},
#    {'score': 0.08452865481376648,
#     'sequence': 'Several climbers in a row are climbing the rock while the man in red watches and holds the camera.',
#     'token': 2280,
#     'token_str': ' camera'},
#    {'score': 0.08339357376098633,
#     'sequence': 'Several climbers in a row are climbing the rock while the man in red watches and holds the ladder.',
#     'token': 16348,
#     'token_str': ' ladder'},
#    {'score': 0.06085050478577614,
#     'sequence': 'Several climbers in a row are climbing the rock while the man in red watches and holds the ropes.',
#     'token': 22502,
#     'token_str': ' ropes'},
#    {'score': 0.01666971482336521,
#     'sequence': 'Several climbers in a row are climbing the rock while the man in red watches and holds the line.',
#     'token': 516,
#     'token_str': ' line'},
#    {'score': 0.01229672972112894,
#     'sequence': 'Several climbers in a row are climbing the rock while the man in red watches and holds the flag.',
#     'token': 3794,
#     'token_str': ' flag'},
#    {'score': 0.011745981872081757,
#     'sequence': 'Several climbers in a row are climbing the rock while the man in red watches and holds the torch.',
#     'token': 24732,
#     'token_str': ' torch'},
#    {'score': 0.009115905500948429,
#     'sequence': 'Several climbers in a row are climbing the rock while the man in red watches and holds the reins.',
#     'token': 16450,
#     'token_str': ' reins'},
#    {'score': 0.008858353830873966,
#     'sequence': 'Several climbers in a row are climbing the rock while the man in red watches and holds the flashlight.',
#     'token': 37575,
#     'token_str': ' flashlight'},
#    {'score': 0.008846938610076904,
#     'sequence': 'Several climbers in a row are climbing the rock while the man in red watches and holds the phone.',
#     'token': 1028,
#     'token_str': ' phone'}]],
#  'sentence_id': 0,
#  'tokens_negative': [[0, 97]],
#  'tokens_positive_eval': [[[0, 16]],
#   [[39, 47]],
#   [[54, 61]],
#   [[65, 68]],
#   [[87, 95]]],
#  'width': '333'}

# %% [markdown]
# Now that we've run `roberta` on all our masked sentences, we can begin to postprocess the masked sentences to filter out bad predictions

# %%
import copy

if False:
    if (cand_word == add_dict['masked_word']) | \
        (cand_word in(people_words)) | \
        (cand_word in(pronoun_words)) | \
        (cand_word in list(set([w for sublist in  [[l.name() for l in syn.lemmas()] for syn in wordnet.synsets(cand_word)] for w in sublist]))) |\
        (str.find(masked_captions[idx], cand_word)>-1) |\
        (nltk.pos_tag([cand_word])[0][1]!= nltk.pos_tag([add_dict['masked_word']])[0][1]):
        pass

def is_valid_caption(pred_caption, masked_word):
    pred_word = pred_caption["token_str"].strip().lower()
    masked_word = masked_word.strip().lower()

    if pred_word == masked_word or pred_word in masked_word or masked_word in pred_word:
        # logging.debug(f"Predicted token == masked token {masked_word}")
        return False

    if pred_word in people_words:
        # logging.debug(f"Predicted word {pred_word} in people words")
        return False

    if pred_word in pronoun_words:
        # logging.debug(f"Predicted word {pred_word} in pronoun words")
        return False

    # TODO append POS of predicted word to it
    if pred_word in set([w for sublist in  [[l.name() for l in syn.lemmas()] for syn in wordnet.synsets(pred_word)] for w in sublist]):
        # logging.debug(f"Predicted word '{pred_word}' is synonym of {masked_word} in: \n\t '{pred_caption['sequence']}'\n")
        return False

    # Don't allow subwords as replacements

    #if nltk.pos_tag([pred_word])[0][1] != nltk.pos_tag([masked_word])[0][1]:
        # logging.debug(f"Predicted word '{pred_word}' is dif POS than {masked_word} in: \n\t '{pred_caption['sequence']}'")
     #   return False

    return True

def create_clean_instance(inst):
    clean_inst = copy.deepcopy(inst)
    del clean_inst["NP_ids"]
    del clean_inst["NPs"]
    del clean_inst["masked_captions"]
    del clean_inst["masked_nps"]
    del clean_inst["pred_captions"]
    clean_inst["orig_caption"] = str(clean_inst["caption"])
    clean_inst["orig_id"] = int(clean_inst["id"])
    clean_inst["orig_sentence_id"] = int(clean_inst["sentence_id"])
    clean_inst["orig_tokens_positive_eval"] = copy.deepcopy(clean_inst["tokens_positive_eval"])
    return clean_inst

def get_img_annotations(inst):
    return [x for x in flickr_anns['annotations'] if x["image_id"] == inst["id"]]

def apply_new_id(anns, image_id, annotation_id):
    for i, ann in enumerate(anns):
        ann["image_id"] = image_id
        ann["id"] = annotation_id
        annotation_id += 1
        anns[i] = ann

    return anns, annotation_id

def find_positive_eval_idx(evals, span):
    # First check for exact span matches
    for idx, eval in enumerate(evals):
        span_check = eval[0] # item is a nested list w/ one item
        if span_check[0] == span[0] and span_check[1] == span[1]:
            return idx, eval
    
    # Now check for one where the end of the span matches
    for idx, eval in enumerate(evals):
        span_check = eval[0] # item is a nested list w/ one item
        if span_check[1] == span[1]:
            return idx, eval

    # Check if the start of the span matches
    for idx, eval in enumerate(evals):
        span_check = eval[0] # item is a nested list w/ one item
        if span_check[0] == span[0]:
            return idx, eval

    # print(f"Can't find suitable span from {evals} to {span}")
    return None, None

def fix_positive_eval_pos(inst, anns):
    # Get span of the original word and find its span in the orig caption
    word = inst["masked_word"]
    caption = inst["orig_caption"]
    new_caption = inst["caption"]
    tokens_pos_eval = inst["tokens_positive_eval"]
    match = re.search(rf"\b{word}\b", caption)
    new_span = match.span()

    # Find the positive_eval_token item in inst that matches up to this
    idx, orig_span = find_positive_eval_idx(tokens_pos_eval, new_span)
    if idx is None:
        # print(f"Couldn't find original span of masked word '{word}' in '{caption}'")
        # print(inst)
        # print()
        return None, None

    inst["tokens_positive_eval_idx"] = idx

    # Swap the starting positive_eval_token item 
    tokens_pos_eval[idx] = [list(new_span)]

    start_idx = idx + 1

    # Move all positive_eval items after it to match back up
    for i, eval in enumerate(tokens_pos_eval[start_idx:]):
        # Unnest the span
        eval = eval[0]

        # Extract the substring represented by the span in the original caption
        orig_substr = caption[eval[0]:eval[1]]

        # Find this substring in the new caption
        new_span = re.search(rf"\b{orig_substr}\b", new_caption)
        if not new_span:
            # print(f"Couldn't find '{orig_substr}' in '{new_caption}'")
            return None, None

        new_span = list(new_span.span())

        # Replace this item in the eval list
        tokens_pos_eval[start_idx + i] = [new_span]

    # Re-align the annotation tokens_positive value
    for i, ann in enumerate(anns):
        # Get the index of ann in the original list
        orig_ann_idx = inst["orig_tokens_positive_eval"].index(ann["tokens_positive"])
        # The ordering of the new tokens_positive is the same,
        # so copy the NEW tokens_positive eval back into this object
        ann["tokens_positive"] = copy.deepcopy(tokens_pos_eval[orig_ann_idx])
        # Save back to the annotations list
        anns[i] = ann

    # Save the list back to the instance
    inst["tokens_positive_eval"] = tokens_pos_eval

    return inst, anns

def unroll_instance(inst, image_id, sentence_id, annotation_id):
    imgs = []
    anns = []

    annotations = get_img_annotations(inst)

    # For each masked caption, unroll the predicted captions and create a new instance
    # We'll want to store the masked caption and the masked NP alongside each instance
    # so should iterate over both lists
    for masked_caption, masked_np, pred_captions in zip(inst["masked_captions"], inst["masked_nps"], inst["pred_captions"]):
        max_score = max([x["score"] for x in pred_captions])
        
        for i, pred_caption in enumerate(pred_captions):
            # Exclude if it's an invalid caption
            if not is_valid_caption(pred_caption, masked_np):
                continue

            # Otherwise construct a new image instance with the predicted
            # sentence as the caption
            clean_inst = create_clean_instance(inst)
            clean_inst["caption"] = pred_caption["sequence"]
            clean_inst["pred_word"] = pred_caption["token_str"].strip()
            clean_inst["masked_caption"] = masked_caption
            clean_inst["masked_word"] = masked_np
            
            # Calculate the scores
            clean_inst["score_raw"] = pred_caption["score"]
            clean_inst["score_scaled"] = pred_caption["score"] / max_score
            clean_inst["score_k"] = i

            # Apply the new IDs
            clean_inst["id"] = image_id
            clean_inst["sentence_id"] = sentence_id

            # Duplicate all associated annotations for this new instance
            new_anns = copy.deepcopy(annotations)

            # Reposition the tokens_positive_eval and tokens_positive of the image / annotation.
            # The masked word may be of different length so we need to reposition
            # the tokens_positive_eval indices
            clean_inst, new_anns = fix_positive_eval_pos(clean_inst, new_anns)

            if not clean_inst:
                # Don't save the instance if it fails the previous checks
                continue

            new_anns, annotation_id = apply_new_id(new_anns, image_id, annotation_id)

            # Save the instance
            image_id += 1
            sentence_id += 1
            anns.extend(new_anns)
            imgs.append(clean_inst)

    return imgs, anns, image_id, sentence_id, annotation_id

unroll_instance(masked_instances[471], 0, 0, 0)
# len(unroll_instance(masked_instances[0])), unroll_instance(masked_instances[0])
# Out:
# ([], [], 0, 0, 0)

# %%
filtered_instances = []
new_annotations = []

image_id = 0
sentence_id = 0
annotation_id = 0
last_orig_img_id = None
for inst in tqdm(masked_instances):
    # Reset the sentence_id if we reach a new image
    new_orig_img_id = inst["original_img_id"]
    if last_orig_img_id is None or last_orig_img_id != new_orig_img_id:
        sentence_id = 0
    last_orig_img_id = new_orig_img_id

    # Process this image into multiple versions (with different predicted captions)
    imgs, anns, image_id, sentence_id, annotation_id = unroll_instance(
        inst, image_id, sentence_id, annotation_id)
    
    filtered_instances.extend(imgs)
    new_annotations.extend(anns)

print(image_id, annotation_id)
print(len(filtered_instances), len(new_annotations))
assert image_id == len(filtered_instances)
assert sentence_id < 100 # Ensure it gets reset to 0 fairly often
assert annotation_id == len(new_annotations)
assert all([isinstance(x, dict) for x in new_annotations]) # Ensure the annotations are well-formed
# Out:
#   0%|          | 0/4158 [00:00<?, ?it/s]
# 7893 27727
# 7893 27727

# %%
import random
print(len(masked_instances), len(filtered_instances))
random.choices(filtered_instances, k=3)
# Out:
# 4158 7893
# [{'caption': 'Michael is getting some serious air while the more formally dressed group gathers in the background.',
#   'dataset_name': 'flickr',
#   'file_name': '411008311.jpg',
#   'height': '333',
#   'id': 6720,
#   'masked_caption': '<mask> is getting some serious air while the more formally dressed group gathers in the background .',
#   'masked_word': 'Someone',
#   'orig_caption': 'Someone is getting some serious air while the more formally dressed group gathers in the background .',
#   'orig_id': 158134,
#   'orig_sentence_id': 1,
#   'orig_tokens_positive_eval': [[[0, 7]], [[42, 81]]],
#   'original_img_id': 411008311,
#   'pred_word': 'Michael',
#   'score_k': 5,
#   'score_raw': 0.009471684694290161,
#   'score_scaled': 0.1838726480996371,
#   'sentence_id': 2,
#   'tokens_negative': [[0, 101]],
#   'tokens_positive_eval': [[[0, 7]], [[42, 81]]],
#   'tokens_positive_eval_idx': 0,
#   'width': '500'},
#  {'caption': 'A group of people wait on the sidewalk, wearing coats.',
#   'dataset_name': 'flickr',
#   'file_name': '4672132178.jpg',
#   'height': '440',
#   'id': 3813,
#   'masked_caption': 'A group of people wait on the sidewalk , wearing <mask> .',
#   'masked_word': 'hats',
#   'orig_caption': 'A group of people wait on the sidewalk , wearing hats .',
#   'orig_id': 156026,
#   'orig_sentence_id': 3,
#   'orig_tokens_positive_eval': [[[0, 17]], [[26, 38]], [[49, 53]]],
#   'original_img_id': 4672132178,
#   'pred_word': 'coats',
#   'score_k': 8,
#   'score_raw': 0.02125479467213154,
#   'score_scaled': 0.04869185446145134,
#   'sentence_id': 12,
#   'tokens_negative': [[0, 55]],
#   'tokens_positive_eval': [[[0, 17]], [[26, 38]], [[49, 53]]],
#   'tokens_positive_eval_idx': 2,
#   'width': '500'},
#  {'caption': 'Shirtless, tattooed man rides skateboard down blurring street near Seattle.',
#   'dataset_name': 'flickr',
#   'file_name': '3027397797.jpg',
#   'height': '362',
#   'id': 2876,
#   'masked_caption': 'Shirtless , tattooed man rides skateboard down blurring street near <mask> .',
#   'masked_word': 'beach',
#   'orig_caption': 'Shirtless , tattooed man rides skateboard down blurring street near beach .',
#   'orig_id': 155421,
#   'orig_sentence_id': 1,
#   'orig_tokens_positive_eval': [[[0, 9]], [[12, 24]], [[47, 62]], [[68, 73]]],
#   'original_img_id': 3027397797,
#   'pred_word': 'Seattle',
#   'score_k': 7,
#   'score_raw': 0.02167721465229988,
#   'score_scaled': 0.423630218614347,
#   'sentence_id': 11,
#   'tokens_negative': [[0, 75]],
#   'tokens_positive_eval': [[[0, 9]], [[12, 24]], [[47, 62]], [[68, 73]]],
#   'tokens_positive_eval_idx': 3,
#   'width': '500'}]

# %% [markdown]
# ## Save the filtered masked captions to our new flickr json

# %%
print(len(filtered_instances), len(new_annotations))
# Out:
# 7893 27727

# %%
with open("data/final_flickr_mergedGT_test.json") as f:
  flickr_anns = json.load(f)

flickr_anns["images"] = filtered_instances
flickr_anns["annotations"] = new_annotations

with open("data/flickr_test_masked.json", mode="w") as f:
    json.dump(flickr_anns, f)

# %% [markdown]
# ### Test the shape of instances before/after is the same

# %%
with open("data/final_flickr_mergedGT_test.json") as f:
  flickr_anns = json.load(f)

with open("output/flickr_test_masked.json") as f:
  flickr_anns_masked = json.load(f)

flickr_anns["images"][0]
# Out:
# {'caption': 'Several climbers in a row are climbing the rock while the man in red watches and holds the line .',
#  'dataset_name': 'flickr',
#  'file_name': '1016887272.jpg',
#  'height': '500',
#  'id': 153901,
#  'original_img_id': 1016887272,
#  'sentence_id': 0,
#  'tokens_negative': [[0, 97]],
#  'tokens_positive_eval': [[[0, 16]],
#   [[39, 47]],
#   [[54, 61]],
#   [[65, 68]],
#   [[87, 95]]],
#  'width': '333'}

# %%
flickr_anns_masked["images"][5]
# Out:
# {'caption': 'Two children playing on the beach in the USA with the ocean in the background',
#  'dataset_name': 'flickr',
#  'file_name': '7162685234.jpg',
#  'height': '333',
#  'id': 5,
#  'masked_caption': 'Two children playing on the beach in the <mask> with the ocean in the background',
#  'masked_word': 'sand',
#  'orig_caption': 'Two children playing on the beach in the sand with the ocean in the background',
#  'orig_id': 153906,
#  'orig_sentence_id': 0,
#  'orig_tokens_positive_eval': [[[0, 12]], [[24, 33]], [[37, 45]], [[51, 60]]],
#  'original_img_id': 7162685234,
#  'pred_word': 'USA',
#  'score_k': 1,
#  'score_raw': 0.04310312494635582,
#  'score_scaled': 0.10239012625063768,
#  'sentence_id': 3,
#  'tokens_negative': [[0, 78]],
#  'tokens_positive_eval': [[[0, 12]], [[24, 33]], [[41, 45]], [[50, 59]]],
#  'tokens_positive_eval_idx': 2,
#  'width': '500'}

# %% [markdown]
# ## Analysis of candidate "negative" captions
# ### Rules for candidates we will exclude:
#
#
# 1.   Synonym of masked word
# 2.   We will not be using man/ woman or other people words for replacement
# 3.   If the word is already in the sentence
# 4.   Is the masked word itself

# %%
candidate_replacements['top_replacement'] = ''
for i in range(10):
  candidate_replacements['top_replacement'] = np.where((candidate_replacements['top_replacement'] == '') & (candidate_replacements[f'Replacement Word {i}'] !=''),
                                                  candidate_replacements[f'Replacement Word {i}'],   candidate_replacements['top_replacement'])  
candidate_replacements[candidate_replacements['top_replacement']!=''][['original_caption', 'masked_caption', 'top_replacement']]
# Out:
#                                       original_caption  \
# 0    Two young , wet boys playing in the sand on a ...
# 1    A topless mannequin with a white skirt is bein...
# 2    A man in a blue shirt , jumping down a hill in...
# 3    A clown is sitting cross-legged on a folding c...
# 4    Two blonds are passing out fliers and balloons...
# ..                                                 ...
# 571  A man in a nun outfit has a cigarette in his m...
# 572  A little boy , who 's face is painted like a z...
# 573  A black man with a hat and shades frowning wit...
# 574           a man works outdoors with some machinery
# 575              A man is milling wood at a festival .
#
#                                         masked_caption top_replacement
# 0    Two young , wet boys playing in the [MASK] on ...             nfl
# 1    A topless mannequin with a white skirt is bein...        broadway
# 2    A man in a blue shirt , jumping down a hill in...             mic
# 3    A [MASK] is sitting cross-legged on a folding ...               |
# 4    Two blonds are passing out fliers and [MASK] o...           gifts
# ..                                                 ...             ...
# 571  A man in a nun outfit has a cigarette in his [...            mice
# 572  A little boy , who 's [MASK] is painted like a...         ##front
# 573  A black man with a hat and [MASK] frowning wit...          frames
# 574             a man works [MASK] with some machinery          chairs
# 575                A man is milling wood at a [MASK] .               |
#
# [576 rows x 3 columns]

# %%
nltk.pos_tag(['walls'])
nltk.pos_tag(['rocks'])
# Out:
# [('rocks', 'NNS')]

# %%
top_10_words_collector = []
top_10_scores_collector  = torch.empty((0,10))
candidate_replacements = pd.DataFrame()
model = model.to(device)
legit_cand_tracker = 0
for i, batch in enumerate(masked_dataloader):
    input_ids = batch[0].to(device)
    attn_mask = batch[1].to(device)
    mask_index = torch.where(input_ids == tokenizer.mask_token_id)[1]
    output = model(input_ids, attn_mask)
    logits = output.logits
    softmax = F.softmax(logits, dim = -1)
    mask_words = softmax[torch.arange(input_ids.shape[0]), mask_index, :]  
    top_10_scores, top_10_tokens = torch.topk(mask_words, 10,dim =1, sorted = True)
    for j in range(top_10_tokens.shape[0]):
        batch_words = []
        idx = i*input_ids.shape[0] + j
        add_dict = {}
        add_dict['original_caption'] = original_captions[idx]
        add_dict['masked_caption'] = masked_captions[idx]
        try:
          mask_idx = str.split(masked_captions[idx],' ').index('[MASK]')
        except:
          continue
        add_dict['masked_word'] = str.split(original_captions[idx], ' ')[mask_idx]
        add_dict['NP_idx'] = mask_idx
        add_dict['img_file'] = [img['file_name'] for img in flickr_anns['images'] if mask_idx in(img['NP_ids'])]
        none_count = 0
        for k in range(top_10_tokens.shape[1]):
            #Check conditions for replacement before adding
            #If word == masked word to replace:
            cand_word = str.replace(tokenizer.decode(top_10_tokens[j,k].detach().cpu()), ' ', '')
            if (cand_word == add_dict['masked_word']) | \
               (cand_word in(people_words)) | \
               (cand_word in(pronoun_words)) | \
               (cand_word in list(set([w for sublist in  [[l.name() for l in syn.lemmas()] for syn in wordnet.synsets(cand_word)] for w in sublist]))) |\
               (str.find(masked_captions[idx], cand_word)>-1) |\
               (nltk.pos_tag([cand_word])[0][1]!= nltk.pos_tag([add_dict['masked_word']])[0][1]):
               
              add_dict[f'Replacement Word {k}'] = None
              add_dict[f'Replacement Score {k}'] = None
              add_dict[f'New Sentence {k}'] = None
              none_count += 1
            else:
              add_dict[f'Replacement Word {k}'] = str.replace(tokenizer.decode(top_10_tokens[j,k].detach().cpu()), ' ', '')
              add_dict[f'Replacement Score {k}'] = top_10_scores[j,k].detach().cpu()
              add_dict[f'New Sentence {k}'] = str.replace(masked_captions[idx], '[MASK]', add_dict[f'Replacement Word {k}'])
        if none_count < 10:
          candidate_replacements = candidate_replacements.append(add_dict, ignore_index = True)
          legit_cand_tracker+= 1
        else:
          continue

    if i % 10 == 0:
        print(f"Running for batch: {i / len(masked_dataloader)}")
        print(add_dict)
        print(f'# sentences w/ legitimate candidates: {legit_cand_tracker}')

candidate_replacements.to_csv('output/candidate_object_replacements.csv')
candidate_replacements
# Out:
# Running for batch: 0.0
# {'original_caption': 'A collage of one person climbing a cliff .', 'masked_caption': 'A collage of one person climbing a [MASK] .', 'masked_word': 'cliff', 'NP_idx': 7, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': 'mt', 'Replacement Score 4': tensor(0.0101), 'New Sentence 4': 'A collage of one person climbing a mt .', 'Replacement Word 5': 'chicago', 'Replacement Score 5': tensor(0.0101), 'New Sentence 5': 'A collage of one person climbing a chicago .', 'Replacement Word 6': 'seattle', 'Replacement Score 6': tensor(0.0092), 'New Sentence 6': 'A collage of one person climbing a seattle .', 'Replacement Word 7': 'antarctica', 'Replacement Score 7': tensor(0.0088), 'New Sentence 7': 'A collage of one person climbing a antarctica .', 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': 'disneyland', 'Replacement Score 9': tensor(0.0085), 'New Sentence 9': 'A collage of one person climbing a disneyland .'}
# # sentences w/ legitimate candidates: 2
# Running for batch: 0.1
# {'original_caption': 'Customers dining at a restaurant .', 'masked_caption': 'Customers dining at a [MASK] .', 'masked_word': 'restaurant', 'NP_idx': 4, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 15
# Running for batch: 0.2
# {'original_caption': 'A dingy indoor scene shows an apparent renovation or construction project in progress , with a drop-cloth on stairs , scaffolding , and a man in hard-hat and orange safety vest looking away outside .', 'masked_caption': 'A dingy indoor scene shows an apparent renovation or construction project in [MASK] , with a drop-cloth on stairs , scaffolding , and a man in hard-hat and orange safety vest looking away outside .', 'masked_word': 'progress', 'NP_idx': 12, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 30
# Running for batch: 0.3
# {'original_caption': 'A woman is looking through binoculars while standing in front of a car that is parked near mountains .', 'masked_caption': 'A woman is looking through binoculars while standing in front of a car that is parked near [MASK] .', 'masked_word': 'mountains', 'NP_idx': 17, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 40
# Running for batch: 0.4
# {'original_caption': 'A small girl in a dress blows bubbles in a grassy field .', 'masked_caption': 'A small girl in a [MASK] blows bubbles in a grassy field .', 'masked_word': 'dress', 'NP_idx': 5, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 55
# Running for batch: 0.5
# {'original_caption': 'A girl in pink slides down the slide at a playground .', 'masked_caption': 'A girl in pink slides down the slide at a [MASK] .', 'masked_word': 'playground', 'NP_idx': 10, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 68
# Running for batch: 0.6
# {'original_caption': 'Two brown dogs walking through snow .', 'masked_caption': 'Two brown dogs walking through [MASK] .', 'masked_word': 'snow', 'NP_idx': 5, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 76
# Running for batch: 0.7
# {'original_caption': 'A group of smiling people sit around a man with a guitar .', 'masked_caption': 'A [MASK] of smiling people sit around a man with a guitar .', 'masked_word': 'group', 'NP_idx': 1, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 89
# Running for batch: 0.8
# {'original_caption': 'An old man sits on a bench overlooking the water .', 'masked_caption': 'An old man sits on a [MASK] overlooking the water .', 'masked_word': 'bench', 'NP_idx': 6, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 101
# Running for batch: 0.9
# {'original_caption': 'Man sitting in a chair hold a cup .', 'masked_caption': 'Man sitting in a chair hold a [MASK] .', 'masked_word': 'cup', 'NP_idx': 7, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 114
#                                       original_caption  \
# 0    A group of people are rock climbing on a rock ...
# 1           A collage of one person climbing a cliff .
# 2    Two children playing on the beach in the sand ...
# 3     A smiling clown is sitting outdoors by his booth
# 4    A blond woman in a crowded area hands out flie...
# ..                                                 ...
# 123  a girl in a red shirt looks at her mom in a cr...
# 124  A group of people with their backs to the came...
# 125  A little girl looking into a females face in t...
# 126  A referee wearing a black and white uniform wa...
# 127  Two small children are playing with toys while...
#
#                                         masked_caption masked_word  NP_idx  \
# 0    A [MASK] of people are rock climbing on a rock...       group     1.0
# 1          A collage of one person climbing a [MASK] .       cliff     7.0
# 2    Two children playing on the beach in the sand ...  background    14.0
# 3       A smiling clown is sitting [MASK] by his booth    outdoors     5.0
# 4    A blond woman in a crowded area hands out [MAS...      fliers     9.0
# ..                                                 ...         ...     ...
# 123  a girl in a red shirt looks at her [MASK] in a...         mom     9.0
# 124  A group of people with their [MASK] to the cam...       backs     6.0
# 125  A little girl looking into a females face in t...       midst    10.0
# 126  A referee wearing a black and white uniform wa...         ice    18.0
# 127  Two small children are playing with [MASK] whi...        toys     6.0
#
#              img_file Replacement Word 0 Replacement Score 0  \
# 0    [1016887272.jpg]               None                None
# 1    [1016887272.jpg]               None                None
# 2    [1016887272.jpg]               None                None
# 3    [1016887272.jpg]             onions      tensor(0.2679)
# 4    [1016887272.jpg]               None                None
# ..                ...                ...                 ...
# 123  [1016887272.jpg]               None                None
# 124  [1016887272.jpg]              boots      tensor(0.5741)
# 125  [1016887272.jpg]               None                None
# 126  [1016887272.jpg]               None                None
# 127  [1016887272.jpg]               None                None
#
#                                         New Sentence 0 Replacement Word 1  \
# 0                                                 None              ##ist
# 1                                                 None               None
# 2                                                 None               None
# 3       A smiling clown is sitting onions by his booth           potatoes
# 4                                                 None               None
# ..                                                 ...                ...
# 123                                               None               None
# 124  A group of people with their boots to the came...               None
# 125                                               None               None
# 126                                               None               None
# 127                                               None               None
#
#     Replacement Score 1  ...  \
# 0        tensor(0.0049)  ...
# 1                  None  ...
# 2                  None  ...
# 3        tensor(0.1327)  ...
# 4                  None  ...
# ..                  ...  ...
# 123                None  ...
# 124                None  ...
# 125                None  ...
# 126                None  ...
# 127                None  ...
#
#                                         New Sentence 6 Replacement Word 7  \
# 0                                                 None             ##ista
# 1         A collage of one person climbing a seattle .         antarctica
# 2                                                 None               None
# 3    A smiling clown is sitting mushrooms by his booth               None
# 4    A blond woman in a crowded area hands out dogs...               None
# ..                                                 ...                ...
# 123                                               None          christmas
# 124  A group of people with their sneakers to the c...               None
# 125                                               None            ##front
# 126                                               None             harley
# 127  Two small children are playing with sports whi...              games
#
#     Replacement Score 7                                     New Sentence 7  \
# 0        tensor(0.0010)  A ##ista of people are rock climbing on a rock...
# 1        tensor(0.0088)    A collage of one person climbing a antarctica .
# 2                  None                                               None
# 3                  None                                               None
# 4                  None                                               None
# ..                  ...                                                ...
# 123      tensor(0.0125)  a girl in a red shirt looks at her christmas i...
# 124                None                                               None
# 125  tensor(2.8356e-06)  A little girl looking into a females face in t...
# 126      tensor(0.0025)  A referee wearing a black and white uniform wa...
# 127      tensor(0.0218)  Two small children are playing with games whil...
#
#     Replacement Word 8 Replacement Score 8  \
# 0                 None                None
# 1                 None                None
# 2                 None                None
# 3             tomatoes      tensor(0.0210)
# 4                 None                None
# ..                 ...                 ...
# 123               None                None
# 124              socks      tensor(0.0067)
# 125               None                None
# 126               None                None
# 127               None                None
#
#                                         New Sentence 8 Replacement Word 9  \
# 0                                                 None               None
# 1                                                 None         disneyland
# 2                                                 None               None
# 3     A smiling clown is sitting tomatoes by his booth             grapes
# 4                                                 None               None
# ..                                                 ...                ...
# 123                                               None               None
# 124  A group of people with their socks to the came...            jackets
# 125                                               None               None
# 126                                               None               None
# 127                                               None               None
#
#     Replacement Score 9                                     New Sentence 9
# 0                  None                                               None
# 1        tensor(0.0085)    A collage of one person climbing a disneyland .
# 2                  None                                               None
# 3        tensor(0.0204)     A smiling clown is sitting grapes by his booth
# 4                  None                                               None
# ..                  ...                                                ...
# 123                None                                               None
# 124      tensor(0.0066)  A group of people with their jackets to the ca...
# 125                None                                               None
# 126                None                                               None
# 127                None                                               None
#
# [128 rows x 35 columns]

# %% [markdown]
# #MLM Object Replacement (Sara's)
# This script is used to create "negative" captions for images from the Flickr30K test dataset using MLM. Steps are roughly as follows:
# ### 1. Identification of objects to mask and replace in captions
#  * We use nltk parsing to extract noun phrases or objects that are candidates for substitution in the captions for the different images
#
# ### 2. Apply MLM to get candidate substitution phrases for masked words
#  * We apply BertForMaskedLM on masked sentences
#
# ### 3. Analysis of candidate "negative" captions
#   * Not all replacement words/ phrases are appropriate. We apply some post-processing to select reasonable candidates from the MLM

# %% [markdown]
# ## Inital Set-up

# %%
# !pip install transformers
# !pip install nltk
# Out:
# Collecting transformers
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 34.6 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 77.3 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 8.2 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 63.2 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 85.8 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=abea877463c6489347adb8751ad75aae0f60a0dad26fc7d7020c2457d1e0a1c6
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built sacremoses
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.5.1 pyyaml-6.0 sacremoses-0.0.53 tokenizers-0.12.1 transformers-4.18.0
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)

# %%
import os, sys
import pandas as pd
import numpy as np
import json
import spacy
import en_core_web_sm
import nltk
from nltk import word_tokenize
from nltk import pos_tag
from transformers import BertTokenizer, BertForMaskedLM
from torch.nn import functional as F
import torch
import re
from nltk.corpus import wordnet

# %%
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
data_dir = '/content/gdrive/MyDrive/DL_systems/final_project/data/'
flickr_anns = json.load(open(os.path.join(data_dir, 'final_flickr_mergedGT_test.json'),'r'))
len(flickr_anns['images'])
len(flickr_anns['annotations'])
# Out:
# 14481

# %% [markdown]
# Example of image data in annotation file:

# %%
flickr_anns['images'][0]
# Out:
# {'caption': 'Several climbers in a row are climbing the rock while the man in red watches and holds the line .',
#  'dataset_name': 'flickr',
#  'file_name': '1016887272.jpg',
#  'height': '500',
#  'id': 153901,
#  'original_img_id': 1016887272,
#  'sentence_id': 0,
#  'tokens_negative': [[0, 97]],
#  'tokens_positive_eval': [[[0, 16]],
#   [[39, 47]],
#   [[54, 61]],
#   [[65, 68]],
#   [[87, 95]]],
#  'width': '333'}

# %% [markdown]
# Example of annotation data in annotation file:

# %%
flickr_anns['annotations'][0]
# Out:
# {'area': 21186.0,
#  'bbox': [74.0, 302.0, 107.0, 198.0],
#  'category_id': 1,
#  'id': 430844,
#  'image_id': 153901,
#  'iscrowd': 0,
#  'phrase_ids': 3,
#  'tokens_positive': [[54, 61]]}

# %% [markdown]
# ## Identification of objects to mask and replace in captions

# %%
article_list = ['the', 'a', 'an']
def parse_NP(sentence):
    '''
    Function for extracting noun phrases from sentences (these will be objects and object + modifiers we will be replacing to create negative captions)
    '''

    #Define grammar for parsing tree
    grammar = """NP: {<DT>?<JJ>*<NN.*>+}
                    RELATION: {<V.*>}
                                {<DT>?<JJ>*<NN.*>+}
                    ENTITY: {<NN.*>}"""
    
    parser = nltk.RegexpParser(grammar)
    NP_list = [' '.join(leaf[0] for leaf in tree.leaves()) for tree in parser.parse(nltk.pos_tag(nltk.word_tokenize(sentence))).subtrees() if tree.label() =='NP']
    
    #remove articles from NP
    NP_list = [' '.join([w for w in str.split(np,' ') if str.lower(w) not in(article_list)]) for np in NP_list]
    return NP_list

# %%
'''Update annotations dictionary (imafge keys specificially to include noun phrases and ids assocaited w/ them)
This is important because these NPs are what we are going to find candidate replacements for using MLM
Each caption can have multiople NPs so we need to have ids associated with each to map back to the original image/caption once we tokenize all the captions and load them in dataloader
'''
np_id = 0
for i, img in enumerate(flickr_anns['images']):
    img['NPs'] = parse_NP(img['caption'])
    img['NP_ids'] = []
    for i in range(len(img['NPs'])):
        #Add in ID for noun phrases for mapping back when we add to dataset
        img['NP_ids'].append(np_id)
        np_id += 1

# %%
flickr_anns['images'][0]
# Out:
# {'NP_ids': [0, 1, 2, 3, 4, 5],
#  'NPs': ['Several climbers', 'row', 'rock', 'man', 'red watches', 'line'],
#  'caption': 'Several climbers in a row are climbing the rock while the man in red watches and holds the line .',
#  'dataset_name': 'flickr',
#  'file_name': '1016887272.jpg',
#  'height': '500',
#  'id': 153901,
#  'original_img_id': 1016887272,
#  'sentence_id': 0,
#  'tokens_negative': [[0, 97]],
#  'tokens_positive_eval': [[[0, 16]],
#   [[39, 47]],
#   [[54, 61]],
#   [[65, 68]],
#   [[87, 95]]],
#  'width': '333'}

# %%
import numpy as np
people_words = np.array(['man', 'woman', 'men', 'women', 'children', 'child', 'girl', 'boy', 'boys', 'girls', 'father', 'fathers', 'son', 'sons', 'husband', 'husbands', 'mother','mothers', 'parent', 'parents', 'daughter', 'daughters', 'wife', 'wives',
                  'spouse', 'spouses', 'partner', 'partners', 'brother', 'brothers', 'sister', 'sisters', 'sibling', 'siblings', 'grandfather','grandfathers',	'grandmother', 'grandmothers',	'grandparents', 'uncle', 'uncles', 'aunt', 'aunts',
                   'nephew', 'nephews', 'niece', 'nieces', 'cousin', 'cousins', 'person', 'people'])
pronoun_words = np.array(["this", "that", "these", "those", "another", "anybody", "anyone", "anything", "each", "either", "enough", "everybody", "everyone",
                "everything", "little", "much", "neither", "nobody", "no one", "nothing", "one", "other", "somebody",
                "something", "both", "few", "fewer", "many", "others", "several", "All", "any", "more", "most",
                "someone", "none", "some", "such", "who", "whom", "whose", "what", "which", 'it', 'them', 'they', 'her', 'she', 'him', 'he', 'I'])

# %%
masked_captions = []
original_captions = []
for i, img in enumerate(flickr_anns['images']):
    caption = img['caption']
    for j in range(len(img['NPs'])):
        NP = img['NPs'][j]
        #print(NP)
        if str.count(caption, NP)>1: 
            continue
        elif len(np.where(np.array([str.find(NP, w) for w in people_words])>-1)[0])>0: 
          continue
        elif len(np.where(np.array([str.find(NP, w) for w in pronoun_words])>-1)[0])>0: 
          continue
        elif len(str.split(NP, ' '))>1:
          continue
        elif str.find(caption, NP)==-1:
          continue
        else:
            masked_captions.append(str.replace(caption, NP, '[MASK]'))
            original_captions.append(caption)
print(f"# masked captions: {len(masked_captions)}")
# Out:
# # masked captions: 7449

# %%
#Randomly sample 1000 masked captions we want to generate replacement phrases for (we don't need all 13,912)
np.random.seed(42)
sample_idx = np.array(np.random.choice(range(len(masked_captions)), size = 1000))
masked_captions_sample = np.array(masked_captions)[sample_idx]
original_captions_sample = np.array(original_captions)[sample_idx]
print(len(masked_captions_sample))
# Out:
# 1000

# %% [markdown]
# ## Apply MLM to get candidate substitution phrases for masked words

# %%
from transformers import BertTokenizer, BertForMaskedLM
from torch.nn import functional as F
import torch
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
def encode(data, tokenizer):
    '''
    Function for encoding captions 
    '''
    input_ids = []
    attention_mask = []
    for text in data:
        tokenized_text = tokenizer.encode_plus(text,
                                            max_length=128,
                                            add_special_tokens = True,
                                            pad_to_max_length=True,
                                            return_attention_mask=True)
        input_ids.append(tokenized_text['input_ids'])
        attention_mask.append(tokenized_text['attention_mask'])
    
    return torch.tensor(input_ids, dtype=torch.long), torch.tensor(attention_mask, dtype=torch.long)

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertForMaskedLM.from_pretrained('bert-base-uncased',    return_dict = True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
use_sample = False
if use_sample:
  input_ids, attention_mask  = encode(masked_captions_sample, tokenizer )
else:
  input_ids, attention_mask  = encode(masked_captions, tokenizer )
masked_dset = torch.utils.data.TensorDataset(input_ids, attention_mask)
masked_dataloader = torch.utils.data.DataLoader(masked_dset, batch_size = 10)
len(masked_dset)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:2269: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# 7449

# %%
device = 'cuda:0'
top_10_words_collector = []
top_10_scores_collector  = torch.empty((0,10))
candidate_replacements = pd.DataFrame()
model = model.to(device)
legit_cand_tracker = 0
for i, batch in enumerate(masked_dataloader):
    input_ids = batch[0].to(device)
    attn_mask = batch[1].to(device)
    mask_index = torch.where(input_ids == tokenizer.mask_token_id)[1]
    output = model(input_ids, attn_mask)
    logits = output.logits
    softmax = F.softmax(logits, dim = -1)
    mask_words = softmax[torch.arange(input_ids.shape[0]), mask_index, :]  
    top_10_scores, top_10_tokens = torch.topk(mask_words, 10,dim =1, sorted = True)
    for j in range(top_10_tokens.shape[0]):
        batch_words = []
        idx = i*input_ids.shape[0] + j
        add_dict = {}
        add_dict['original_caption'] = original_captions[idx]
        add_dict['masked_caption'] = masked_captions[idx]
        try:
          mask_idx = str.split(masked_captions[idx],' ').index('[MASK]')
        except:
          continue
        add_dict['masked_word'] = str.split(original_captions[idx], ' ')[mask_idx]
        add_dict['NP_idx'] = mask_idx
        add_dict['img_file'] = [img['file_name'] for img in flickr_anns['images'] if mask_idx in(img['NP_ids'])]
        none_count = 0
        for k in range(top_10_tokens.shape[1]):
            #Check conditions for replacement before adding
            #If word == masked word to replace:
            cand_word = str.replace(tokenizer.decode(top_10_tokens[j,k].detach().cpu()), ' ', '')
            if (cand_word == add_dict['masked_word']) | \
               (cand_word in(people_words)) | \
               (cand_word in(pronoun_words)) | \
               (cand_word in list(set([w for sublist in  [[l.name() for l in syn.lemmas()] for syn in wordnet.synsets(cand_word)] for w in sublist]))) |\
               (str.find(masked_captions[idx], cand_word)>-1) |\
               (nltk.pos_tag([cand_word])[0][1]!= nltk.pos_tag([add_dict['masked_word']])[0][1]):
               
              add_dict[f'Replacement Word {k}'] = None
              add_dict[f'Replacement Score {k}'] = None
              add_dict[f'New Sentence {k}'] = None
              none_count += 1
            else:
              add_dict[f'Replacement Word {k}'] = str.replace(tokenizer.decode(top_10_tokens[j,k].detach().cpu()), ' ', '')
              add_dict[f'Replacement Score {k}'] = top_10_scores[j,k].detach().cpu()
              add_dict[f'New Sentence {k}'] = str.replace(masked_captions[idx], '[MASK]', add_dict[f'Replacement Word {k}'])
        if none_count < 10:
          candidate_replacements = candidate_replacements.append(add_dict, ignore_index = True)
          legit_cand_tracker+= 1
        else:
          continue

    if i %10 == 0:
        print(f"Running for batch: {i}")
        print(add_dict)
        print(f'# sentences w/ legitimate candidates: {legit_cand_tracker}')
    
candidate_replacements.to_csv(os.path.join(data_dir, 'candidate_object_replacements.csv'))
# Out:
# Running for batch: 0
# {'original_caption': 'A collage of one person climbing a cliff .', 'masked_caption': 'A collage of one person climbing a [MASK] .', 'masked_word': 'cliff', 'NP_idx': 7, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 0
# Running for batch: 10
# {'original_caption': 'Customers dining at a restaurant .', 'masked_caption': 'Customers dining at a [MASK] .', 'masked_word': 'restaurant', 'NP_idx': 4, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 22
# Running for batch: 20
# {'original_caption': 'A dingy indoor scene shows an apparent renovation or construction project in progress , with a drop-cloth on stairs , scaffolding , and a man in hard-hat and orange safety vest looking away outside .', 'masked_caption': 'A dingy indoor scene shows an apparent renovation or construction project in [MASK] , with a drop-cloth on stairs , scaffolding , and a man in hard-hat and orange safety vest looking away outside .', 'masked_word': 'progress', 'NP_idx': 12, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': 'london', 'Replacement Score 7': tensor(0.0024), 'New Sentence 7': 'A dingy indoor scene shows an apparent renovation or construction project in london , with a drop-cloth on stairs , scaffolding , and a man in hard-hat and orange safety vest looking away outside .', 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 46
# Running for batch: 30
# {'original_caption': 'A woman is looking through binoculars while standing in front of a car that is parked near mountains .', 'masked_caption': 'A woman is looking through binoculars while standing in front of a car that is parked near [MASK] .', 'masked_word': 'mountains', 'NP_idx': 17, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': 'ours', 'Replacement Score 6': tensor(0.0207), 'New Sentence 6': 'A woman is looking through binoculars while standing in front of a car that is parked near ours .', 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': 'hers', 'Replacement Score 9': tensor(0.0072), 'New Sentence 9': 'A woman is looking through binoculars while standing in front of a car that is parked near hers .'}
# # sentences w/ legitimate candidates: 74
# Running for batch: 40
# {'original_caption': 'A small girl in a dress blows bubbles in a grassy field .', 'masked_caption': 'A small girl in a [MASK] blows bubbles in a grassy field .', 'masked_word': 'dress', 'NP_idx': 5, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 98
# Running for batch: 50
# {'original_caption': 'A girl in pink slides down the slide at a playground .', 'masked_caption': 'A girl in pink slides down the slide at a [MASK] .', 'masked_word': 'playground', 'NP_idx': 10, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 118
# Running for batch: 60
# {'original_caption': 'Two brown dogs walking through snow .', 'masked_caption': 'Two brown dogs walking through [MASK] .', 'masked_word': 'snow', 'NP_idx': 5, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 135
# Running for batch: 70
# {'original_caption': 'A group of smiling people sit around a man with a guitar .', 'masked_caption': 'A [MASK] of smiling people sit around a man with a guitar .', 'masked_word': 'group', 'NP_idx': 1, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 156
# Running for batch: 80
# {'original_caption': 'An old man sits on a bench overlooking the water .', 'masked_caption': 'An old man sits on a [MASK] overlooking the water .', 'masked_word': 'bench', 'NP_idx': 6, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 186
# Running for batch: 90
# {'original_caption': 'Man sitting in a chair hold a cup .', 'masked_caption': 'Man sitting in a chair hold a [MASK] .', 'masked_word': 'cup', 'NP_idx': 7, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 214
# Running for batch: 100
# {'original_caption': 'A brown dog is jumping over a pole with fire on the ends .', 'masked_caption': 'A brown dog is jumping over a pole with [MASK] on the ends .', 'masked_word': 'fire', 'NP_idx': 9, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 241
# Running for batch: 110
# {'original_caption': 'A couple sitting in front of a computer screen .', 'masked_caption': 'A couple sitting in [MASK] of a computer screen .', 'masked_word': 'front', 'NP_idx': 4, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': '##front', 'Replacement Score 7': tensor(6.6520e-06), 'New Sentence 7': 'A couple sitting in ##front of a computer screen .', 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 268
# Running for batch: 120
# {'original_caption': 'The fashionably dressed young woman peers at an object in her hand .', 'masked_caption': 'The fashionably dressed young woman peers at an [MASK] in her hand .', 'masked_word': 'object', 'NP_idx': 8, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': 'ipad', 'Replacement Score 7': tensor(0.0088), 'New Sentence 7': 'The fashionably dressed young woman peers at an ipad in her hand .', 'Replacement Word 8': 'iphone', 'Replacement Score 8': tensor(0.0087), 'New Sentence 8': 'The fashionably dressed young woman peers at an iphone in her hand .', 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 285
# Running for batch: 130
# {'original_caption': 'A bunch of kids climbing sliding and playing on a really cool playground .', 'masked_caption': 'A bunch of kids climbing sliding and [MASK] on a really cool playground .', 'masked_word': 'playing', 'NP_idx': 7, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 303
# Running for batch: 140
# {'original_caption': 'Two men on a snowy and rocky mountainside cook a meal while their teammates sit a little way away .', 'masked_caption': 'Two men on a snowy and rocky mountainside cook a [MASK] while their teammates sit a little way away .', 'masked_word': 'meal', 'NP_idx': 10, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 328
# Running for batch: 150
# {'original_caption': 'Soldiers washing dishes in tubs on the street .', 'masked_caption': 'Soldiers washing dishes in tubs on the [MASK] .', 'masked_word': 'street', 'NP_idx': 7, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': 'roofs', 'Replacement Score 9': tensor(0.0197), 'New Sentence 9': 'Soldiers washing dishes in tubs on the roofs .'}
# # sentences w/ legitimate candidates: 360
# Running for batch: 160
# {'original_caption': 'A skateboarder is doing a trick in the air with his skateboard on a red ramp while people stand around looking .', 'masked_caption': 'A skateboarder is doing a trick in the [MASK] with his skateboard on a red ramp while people stand around looking .', 'masked_word': 'air', 'NP_idx': 8, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 386
# Running for batch: 170
# {'original_caption': '2 people on bikes riding away on the distant road with their backs toward us as the road they are on extends on into the distance .', 'masked_caption': '2 people on bikes riding away on the distant road with their [MASK] toward us as the road they are on extends on into the distance .', 'masked_word': 'backs', 'NP_idx': 12, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': 'heads', 'Replacement Score 3': tensor(0.0190), 'New Sentence 3': '2 people on bikes riding away on the distant road with their heads toward us as the road they are on extends on into the distance .', 'Replacement Word 4': 'guns', 'Replacement Score 4': tensor(0.0057), 'New Sentence 4': '2 people on bikes riding away on the distant road with their guns toward us as the road they are on extends on into the distance .', 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': 'rifles', 'Replacement Score 9': tensor(0.0005), 'New Sentence 9': '2 people on bikes riding away on the distant road with their rifles toward us as the road they are on extends on into the distance .'}
# # sentences w/ legitimate candidates: 411
# Running for batch: 180
# {'original_caption': 'A guy in jeans jumping and doing a trick in front of a building .', 'masked_caption': 'A guy in jeans jumping and doing a trick in front of a [MASK] .', 'masked_word': 'building', 'NP_idx': 13, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 436
# Running for batch: 190
# {'original_caption': 'A dog holding a ring in his mouth is standing in a small river .', 'masked_caption': 'A dog holding a ring in his [MASK] is standing in a small river .', 'masked_word': 'mouth', 'NP_idx': 7, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 464
# Running for batch: 200
# {'original_caption': 'A guy in a yellow hat talking into a microphone .', 'masked_caption': 'A [MASK] in a yellow hat talking into a microphone .', 'masked_word': 'guy', 'NP_idx': 1, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 487
# Running for batch: 210
# {'original_caption': 'A person walking down a lonely corridor of columns .', 'masked_caption': 'A person walking down a lonely corridor of [MASK] .', 'masked_word': 'columns', 'NP_idx': 8, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 505
# Running for batch: 220
# {'original_caption': 'A woman in black and white is on a bicycle .', 'masked_caption': 'A woman in black and white is on a [MASK] .', 'masked_word': 'bicycle', 'NP_idx': 9, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 521
# Running for batch: 230
# {'original_caption': 'A small to medium sized white short-haired dog is looking up at an owner not in the photo .', 'masked_caption': 'A small to medium sized white short-haired dog is looking up at an owner not in the [MASK] .', 'masked_word': 'photo', 'NP_idx': 17, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 543
# Running for batch: 240
# {'original_caption': 'There is a baseball player standing at home plate , the catcher behind him has his hand up in the air with his glove , and the umpire is standing behind him , and many people in the stands .', 'masked_caption': 'There is a baseball player standing at home plate , the catcher behind him has his hand up in the air with his glove , and the umpire is standing behind him , and many people in the [MASK] .', 'masked_word': 'stands', 'NP_idx': 38, 'img_file': ['7162685234.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 559
# Running for batch: 250
# {'original_caption': 'A rock concert in progress , with the two musicians and a singer performing as jets of flame shoot up from the stage .', 'masked_caption': 'A rock concert in progress , with the two musicians and a singer performing as jets of [MASK] shoot up from the stage .', 'masked_word': 'flame', 'NP_idx': 17, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 576
# Running for batch: 260
# {'original_caption': 'The snowboarder is in the air .', 'masked_caption': 'The [MASK] is in the air .', 'masked_word': 'snowboarder', 'NP_idx': 1, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 593
# Running for batch: 270
# {'original_caption': 'A lady in a long black dress is standing in a room with tables and chairs holding her arms behind her back .', 'masked_caption': 'A lady in a long black dress is standing in a [MASK] with tables and chairs holding her arms behind her back .', 'masked_word': 'room', 'NP_idx': 11, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 607
# Running for batch: 280
# {'original_caption': 'Two young stylish people walk enthusiastically down a city street at night .', 'masked_caption': 'Two young stylish people walk enthusiastically down a city street at [MASK] .', 'masked_word': 'night', 'NP_idx': 11, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 629
# Running for batch: 290
# {'original_caption': 'A dirt bike rider is in the air pulling off a trick .', 'masked_caption': 'A dirt bike rider is in the [MASK] pulling off a trick .', 'masked_word': 'air', 'NP_idx': 7, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 640
# Running for batch: 300
# {'original_caption': 'Two martial art athletes compete in front of an audience , carefully monitored by the judge .', 'masked_caption': 'Two martial art athletes compete in front of an [MASK] , carefully monitored by the judge .', 'masked_word': 'audience', 'NP_idx': 9, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 663
# Running for batch: 310
# {'original_caption': 'A scientist intently looks through a microscope in a laboratory .', 'masked_caption': 'A scientist intently looks through a microscope in a [MASK] .', 'masked_word': 'laboratory', 'NP_idx': 9, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 683
# Running for batch: 320
# {'original_caption': 'Two young men in blue holding a loudspeaker with one talking .', 'masked_caption': 'Two young men in blue holding a [MASK] with one talking .', 'masked_word': 'loudspeaker', 'NP_idx': 7, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 704
# Running for batch: 330
# {'original_caption': 'A boy in blue shorts running on a concrete surface while holding goggles .', 'masked_caption': 'A boy in blue shorts running on a concrete surface while holding [MASK] .', 'masked_word': 'goggles', 'NP_idx': 12, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': 'weights', 'Replacement Score 1': tensor(0.0545), 'New Sentence 1': 'A boy in blue shorts running on a concrete surface while holding weights .', 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 726
# Running for batch: 340
# {'original_caption': 'A line of people are leaving the sidewalk and entering a yellow school bus .', 'masked_caption': 'A [MASK] of people are leaving the sidewalk and entering a yellow school bus .', 'masked_word': 'line', 'NP_idx': 1, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 740
# Running for batch: 350
# {'original_caption': 'A cyclist and his bicycle hop over an obstacle .', 'masked_caption': 'A cyclist and his bicycle hop over an [MASK] .', 'masked_word': 'obstacle', 'NP_idx': 8, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 751
# Running for batch: 360
# {'original_caption': 'A woman is holding a baby and smiling .', 'masked_caption': 'A woman is holding a [MASK] and smiling .', 'masked_word': 'baby', 'NP_idx': 5, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 768
# Running for batch: 370
# {'original_caption': 'A person in a sweater sits looking at a book with a child on their lap .', 'masked_caption': 'A person in a [MASK] sits looking at a book with a child on their lap .', 'masked_word': 'sweater', 'NP_idx': 4, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 785
# Running for batch: 380
# {'original_caption': 'A dark-haired woman is placing a label on a cigar .', 'masked_caption': 'A dark-haired woman is placing a [MASK] on a cigar .', 'masked_word': 'label', 'NP_idx': 6, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 803
# Running for batch: 390
# {'original_caption': 'A guy wearing protective pants is carving an owl on a perch out of wood using a chainsaw .', 'masked_caption': 'A guy wearing protective pants is carving an owl on a perch out of wood using a [MASK] .', 'masked_word': 'chainsaw', 'NP_idx': 17, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 823
# Running for batch: 400
# ...
# # sentences w/ legitimate candidates: 1275
# Running for batch: 620
# {'original_caption': 'A young lady wearing blue and black is running past an orange cone .', 'masked_caption': 'A young lady wearing [MASK] and black is running past an orange cone .', 'masked_word': 'blue', 'NP_idx': 4, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 1288
# Running for batch: 630
# {'original_caption': 'The little boy is playing with a croquet hammer and ball beside the car .', 'masked_caption': 'The little boy is playing with a croquet hammer and ball beside the [MASK] .', 'masked_word': 'car', 'NP_idx': 13, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 1310
# Running for batch: 640
# {'original_caption': 'A woman in a bathing suit hangs on the side of a swimming pool .', 'masked_caption': 'A woman in a bathing suit hangs on the [MASK] of a swimming pool .', 'masked_word': 'side', 'NP_idx': 9, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 1325
# Running for batch: 650
# {'original_caption': 'Three men rest on the steps near the entrance in full Roman attire .', 'masked_caption': 'Three men rest on the [MASK] near the entrance in full Roman attire .', 'masked_word': 'steps', 'NP_idx': 5, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': 'benches', 'Replacement Score 2': tensor(0.0373), 'New Sentence 2': 'Three men rest on the benches near the entrance in full Roman attire .', 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 1336
# Running for batch: 660
# {'original_caption': 'A bearded man jumps in the snow with the ocean in the background and an orange , recumbent bike parked near a road sign .', 'masked_caption': 'A bearded man jumps in the snow with the [MASK] in the background and an orange , recumbent bike parked near a road sign .', 'masked_word': 'ocean', 'NP_idx': 9, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 1351
# Running for batch: 670
# {'original_caption': 'Man performing a dance in the street .', 'masked_caption': 'Man performing a [MASK] in the street .', 'masked_word': 'dance', 'NP_idx': 3, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 1371
# Running for batch: 680
# {'original_caption': 'A man with parted hair and wearing glasses is seated outdoors on a bench where he is reading .', 'masked_caption': 'A man with parted hair and wearing glasses is seated outdoors on a [MASK] where he is reading .', 'masked_word': 'bench', 'NP_idx': 13, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 1391
# Running for batch: 690
# {'original_caption': 'Large seated group of people with a sign in the photo that says " Gladstone School "', 'masked_caption': 'Large seated [MASK] of people with a sign in the photo that says " Gladstone School "', 'masked_word': 'group', 'NP_idx': 2, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': 'crowds', 'Replacement Score 2': tensor(0.1166), 'New Sentence 2': 'Large seated crowds of people with a sign in the photo that says " Gladstone School "', 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 1406
# Running for batch: 700
# {'original_caption': 'A well dressed man in front of a microphone is attacked by a dragon pinata and a lady .', 'masked_caption': 'A [MASK] dressed man in front of a microphone is attacked by a dragon pinata and a lady .', 'masked_word': 'well', 'NP_idx': 1, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 1420
# Running for batch: 710
# {'original_caption': 'A group of people are watching a plane flying low .', 'masked_caption': 'A [MASK] of people are watching a plane flying low .', 'masked_word': 'group', 'NP_idx': 1, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 1442
# Running for batch: 720
# {'original_caption': 'One biker doing a stunt while onlookers watch in the far corner .', 'masked_caption': 'One [MASK] doing a stunt while onlookers watch in the far corner .', 'masked_word': 'biker', 'NP_idx': 1, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 1462
# Running for batch: 730
# {'original_caption': 'The hiker pokes out of her tent to find that snow is everywhere .', 'masked_caption': 'The [MASK] pokes out of her tent to find that snow is everywhere .', 'masked_word': 'hiker', 'NP_idx': 1, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 1486
# Running for batch: 740
# {'original_caption': 'A man in a hat and hoodie is standing near a building advertisement with a cat on his shoulder .', 'masked_caption': 'A man in a hat and hoodie is standing near a building advertisement with a cat on his [MASK] .', 'masked_word': 'shoulder', 'NP_idx': 18, 'img_file': ['1016887272.jpg'], 'Replacement Word 0': None, 'Replacement Score 0': None, 'New Sentence 0': None, 'Replacement Word 1': None, 'Replacement Score 1': None, 'New Sentence 1': None, 'Replacement Word 2': None, 'Replacement Score 2': None, 'New Sentence 2': None, 'Replacement Word 3': None, 'Replacement Score 3': None, 'New Sentence 3': None, 'Replacement Word 4': None, 'Replacement Score 4': None, 'New Sentence 4': None, 'Replacement Word 5': None, 'Replacement Score 5': None, 'New Sentence 5': None, 'Replacement Word 6': None, 'Replacement Score 6': None, 'New Sentence 6': None, 'Replacement Word 7': None, 'Replacement Score 7': None, 'New Sentence 7': None, 'Replacement Word 8': None, 'Replacement Score 8': None, 'New Sentence 8': None, 'Replacement Word 9': None, 'Replacement Score 9': None, 'New Sentence 9': None}
# # sentences w/ legitimate candidates: 1502

# %% [markdown]
# ## Analysis of candidate "negative" captions
# ### Rules for candidates we will exclude:
#
#
# 1.   Synonym of masked word
# 2.   We will not be using man/ woman or other people words for replacement
# 3.   If the word is already in the sentence
# 4.   Is the masked word itself

# %%
candidate_replacements.fillna('', inplace = True)

# %%
candidate_replacements['top_replacement'] = ''
for i in range(10):
  candidate_replacements['top_replacement'] = np.where((candidate_replacements['top_replacement'] == '') & (candidate_replacements[f'Replacement Word {i}'] !=''),
                                                  candidate_replacements[f'Replacement Word {i}'],   candidate_replacements['top_replacement'])  
candidate_replacements[candidate_replacements['top_replacement']!=''][['original_caption', 'masked_caption', 'top_replacement']]
# Out:
#                                       original_caption  \
# 0    Two young , wet boys playing in the sand on a ...
# 1    A topless mannequin with a white skirt is bein...
# 2    A man in a blue shirt , jumping down a hill in...
# 3    A clown is sitting cross-legged on a folding c...
# 4    Two blonds are passing out fliers and balloons...
# ..                                                 ...
# 571  A man in a nun outfit has a cigarette in his m...
# 572  A little boy , who 's face is painted like a z...
# 573  A black man with a hat and shades frowning wit...
# 574           a man works outdoors with some machinery
# 575              A man is milling wood at a festival .
#
#                                         masked_caption top_replacement
# 0    Two young , wet boys playing in the [MASK] on ...             nfl
# 1    A topless mannequin with a white skirt is bein...        broadway
# 2    A man in a blue shirt , jumping down a hill in...             mic
# 3    A [MASK] is sitting cross-legged on a folding ...               |
# 4    Two blonds are passing out fliers and [MASK] o...           gifts
# ..                                                 ...             ...
# 571  A man in a nun outfit has a cigarette in his [...            mice
# 572  A little boy , who 's [MASK] is painted like a...         ##front
# 573  A black man with a hat and [MASK] frowning wit...          frames
# 574             a man works [MASK] with some machinery          chairs
# 575                A man is milling wood at a [MASK] .               |
#
# [576 rows x 3 columns]

# %%
nltk.pos_tag(['walls'])
nltk.pos_tag(['rocks'])
# Out:
# [('rocks', 'NNS')]

# %%
candidate_replacements[candidate_replacements['top_replacement']!=''][['original_caption', 'masked_caption', 'top_replacement']]
# Out:
#                                         original_caption  \
# 19     Several climbers in a row are climbing the roc...
# 38     Seven climbers are ascending a rock face whils...
# 39     Seven climbers are ascending a rock face whils...
# 101    Two children playing on the beach in the sand ...
# 102    Two children playing on the beach in the sand ...
# ...                                                  ...
# 43025            A man known as Deleon speaks at a Q&A .
# 43026            A man known as Deleon speaks at a Q&A .
# 43027            A man known as Deleon speaks at a Q&A .
# 43028            A man known as Deleon speaks at a Q&A .
# 43029            A man known as Deleon speaks at a Q&A .
#
#                                           masked_caption top_replacement
# 19     Several climbers in a row are climbing the [MA...           walls
# 38     Seven climbers are ascending a rock face whils...           reins
# 39     Seven climbers are ascending a rock face whils...           reins
# 101    Two children playing on the beach in the [MASK...           rocks
# 102    Two children playing on the beach in the [MASK...           rocks
# ...                                                  ...             ...
# 43025            A man known as [MASK] speaks at a Q&A .            toys
# 43026            A man known as [MASK] speaks at a Q&A .            toys
# 43027            A man known as [MASK] speaks at a Q&A .            toys
# 43028            A man known as [MASK] speaks at a Q&A .            toys
# 43029            A man known as [MASK] speaks at a Q&A .            toys
#
# [13295 rows x 3 columns]
